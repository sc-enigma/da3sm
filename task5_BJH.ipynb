# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import pandas as pd

from scipy.interpolate import Akima1DInterpolator as Akima

sys.path.append('./Components')

from ASAP2400file import ASAP2400file
from BJHcalculator import BJHcalculator

# %%
# read sample data
filename_sample = r'data/PdAl2O3-AP.txt'
asap_file = ASAP2400file(filename_sample)
pp0 = np.array(asap_file.DesPP0)
des = np.array(asap_file.DesUptake)

# BJH calculation
calculator = BJHcalculator(pp0, des)
calculator.run()
