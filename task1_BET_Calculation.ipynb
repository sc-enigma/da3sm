# %% [markdown]
# # Расчёт удельной поверхности по уравнению БЭТ, методу t-кривых, методу &alpha;<sub>S</sub>-кривых

# %%
import sys
import numpy as np

sys.path.append('./Components')

from ASAP2400file import ASAP2400file
from BETCalculator import BETCalculator

# %%
# read sample data
filename_sample = r'data/PdAl2O3-AP.txt'
asap_file = ASAP2400file(filename_sample)
pp0 = np.array(asap_file.AdsPP0)
ads = np.array(asap_file.AdsUptake)

# BET calculation
calculator = BETCalculator(pp0, ads)
calculator.run()
# Out:
# Удельная поверхность 434.59 кв.м/г
# Константа С 139.72
