# %%
import numpy as np
import sys

sys.path.append('./Components')

from ASAP2400file import ASAP2400file
from TCurveCalculator import TCurveCalculator

# %%
# read sample data
filename_sample = r'data/PdAl2O3-AP.txt'
asap_file = ASAP2400file(filename_sample)
pp0 = np.array(asap_file.AdsPP0)
ads = np.array(asap_file.AdsUptake)

# t curve method calculation
calculator = TCurveCalculator(pp0, ads)
calculator.run()
# Out:
# as     434.59 m^2/g
# as_ext 390.57 m^2/g
# as_mic  44.02 m^2/g
